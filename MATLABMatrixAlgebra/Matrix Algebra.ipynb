# %%
# %pylab inline
# %load_ext oct2py.ipython
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%octave
# M = [1/3,1/4,1/5; 1/4,1/5,1/6; 1/5,1/6,1/7]
# transpose = M'
# inverse = inv (M)
# M * inv (M)
# determinant = det (M)
# #rank=rank(M)
# #trace=trace(M)
# vsingular=svd(M)
# condition =cond(M)
# norm_m=norm(M)
# norm_m_1=norm(M,1)
# norm_m_inf=norm(M,inf)
# norm_m_fro=norm(M,"fro")
# m__3=M^3
# logm_m=logm(M)
# sqrtm_m=sqrtm(M)
# expm_m=expm(M)
# expm1_m=expm1(M)
# #expm2_m=expm2(M)
# Out:
# M =
#
#   0.33333  0.25000  0.20000
#   0.25000  0.20000  0.16667
#   0.20000  0.16667  0.14286
#
# transpose =
#
#   0.33333  0.25000  0.20000
#   0.25000  0.20000  0.16667
#   0.20000  0.16667  0.14286
#
# inverse =
#
#   1.0e+03  *
#
#   0.30000  -0.90000  0.63000
#   -0.90000  2.88000  -2.10000
#   0.63000  -2.10000  1.57500
#
# ans =
#
#   1.00000  -0.00000  0.00000
#   0.00000  1.00000  0.00000
#   0.00000  -0.00000  1.00000
#
# determinant =    2.6455e-06
# vsingular =
#
#   0.65705
#   0.01893
#   0.00021
#
# condition =  3088.6
# norm_m =  0.65705
# norm_m_1 =  0.78333
# norm_m_inf =  0.78333
# norm_m_fro =  0.65732
# m__3 =
#
#   0.14025  0.10955  0.09006
#   0.10955  0.08558  0.07035
#   0.09006  0.07035  0.05784
#
# logm_m =
#
#   -2.47656  2.21997  0.50212
#   2.21997  -5.64209  2.89537
#   0.50212  2.89537  -4.72401
#
# sqrtm_m =
#
#   0.46312  0.28322  0.19658
#   0.28322  0.26540  0.22215
#   0.19658  0.22215  0.23423
#
# expm_m =
#
#   1.46792  0.35503  0.28629
#   0.35503  1.28209  0.23417
#   0.28629  0.23417  1.19841
#
# expm1_m =
#
#   0.39561  0.28403  0.22140
#   0.28403  0.22140  0.18136
#   0.22140  0.18136  0.15356

# %%
# %%octave
# A=[1 1 0;0 1 1;0 0 1]
# B=[i 1-i 2+i;0 -1 3-i;0 0 -i]
# C=[1 1 1; 0 sqrt(2)*i -sqrt(2)*i;1 -1 -1]
# M1=A*B-B*A
# M2=A^2+B^2+C^2
# M3=A*B*C
# M4=sqrtm(A)+sqrtm(B)-sqrtm(C)
# M5=expm(A)*(expm(B)+expm(C))
# ranks=[rank(A) rank(B) rank(C)]
# vsingular=[svd(A),svd(B),svd(C)]
# traces=[trace(A) trace(B) trace(C)]
# inv_a=inv(A)
# inv_b=inv(B)
# inv_c=inv(C)
# #determinants = [det(A) ;det (B) ;det (C)]
# #conditions = [cond(A) cond (B) cond(C)]
# Out:
# A =
#
#         1        1        0
#         0        1        1
#         0        0        1
#
# B =
#
#         0 +      1i        1 -      1i        2 +      1i
#         0 +      0i       -1 +      0i        3 -      1i
#         0 +      0i        0 +      0i       -0 -      1i
#
# C =
#
#   1.00000 + 0.00000i  1.00000 + 0.00000i  1.00000 + 0.00000i
#   0.00000 + 0.00000i  0.00000 + 1.41421i  -0.00000 - 1.41421i
#   1.00000 + 0.00000i  -1.00000 + 0.00000i  -1.00000 + 0.00000i
#
# M1 =
#
#         0 +      0i       -1 -      1i        2 +      0i
#         0 +      0i        0 +      0i        1 -      1i
#         0 +      0i        0 +      0i        0 +      0i
#
# M2 =
#
#   2.00000 + 0.00000i  2.00000 + 3.41421i  3.00000 - 5.41421i
#   0.00000 - 1.41421i  -0.00000 + 1.41421i  0.00000 - 0.58579i
#   0.00000 + 0.00000i  2.00000 - 1.41421i  2.00000 + 1.41421i
#
# M3 =
#
#   5.00000 + 1.00000i  -3.58579 + 1.00000i  -6.41421 + 1.00000i
#   3.00000 - 2.00000i  -3.00000 + 0.58579i  -3.00000 + 3.41421i
#   0.00000 - 1.00000i  0.00000 + 1.00000i  0.00000 + 1.00000i
#
# M4 =
#
#   0.63561 + 0.83610i  -0.32504 - 0.82044i  3.07337 + 1.28963i
#   0.15815 - 0.15207i  0.08957 + 0.57023i  3.30289 - 1.80246i
#   -0.37400 - 0.26540i  0.74721 + 0.33699i  1.22545 + 0.10476i
#
# M5 =
#
#   1.0e+01  *
#
#   1.41906 - 0.00822i  0.54400 + 0.42724i  1.79169 - 0.95842i
#   0.45854 - 0.14972i  0.06830 + 0.21575i  0.85597 - 0.76573i
#   0.35528 + 0.03560i  0.01008 - 0.07488i  0.32433 - 0.18406i
#
# ranks =
#
#         3        3        3
#
# vsingular =
#
#   1.80194  4.21303  2.00000
#   1.24698  1.49167  2.00000
#   0.44504  0.15912  1.41421
#
# traces =
#
#   3.00000 + 0.00000i  -1.00000 + 0.00000i  0.00000 + 1.41421i
#
# inv_a =
#
#         1       -1        1
#         0        1       -1
#         0        0        1
#
# inv_b =
#
#         0 -      1i       -1 -      1i       -4 +      3i
#         0 +      0i       -1 -      0i        1 +      3i
#         0 +      0i        0 +      0i       -0 +      1i
#
# inv_c =
#
#   0.50000 + 0.00000i  0.00000 + 0.00000i  0.50000 + 0.00000i
#   0.25000 + 0.00000i  0.00000 - 0.35355i  -0.25000 + 0.00000i
#   0.25000 + 0.00000i  0.00000 + 0.35355i  -0.25000 + 0.00000i

# %%
# %%octave
#
# M = [1/3,1/4,1/5; 1/4,1/5,1/6; 1/5,1/6,1/7]
#
# #transpose = transpose(M)
#
# inverse=inv(M)
#
# determinant=det(M)
#
# #rank=rank(M)
#
# #trace=trace(M)
#
# #numeric(svd (M))
# Out:
# ---------------------------------------------------------------------------
# OctaveMagicError                          Traceback (most recent call last)
# <ipython-input-23-9ae7ec4069a7> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'octave', u'', u'\nM = [1/3,1/4,1/5; 1/4,1/5,1/6; 1/5,1/6,1/7]\n\n#transpose = transpose(M)\n\ninverse=inv(M)\n\ndeterminant=det(M)\n\n#rank=rank(M)\n\n#trace=trace(M)\n\nnumeric(svd (M))')
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2160             magic_arg_s = self.var_expand(line, stack_depth)
#    2161             with self.builtin_trap:
# -> 2162                 result = fn(magic_arg_s, cell)
#    2163             return result
#    2164
#
# /usr/local/lib/python2.7/dist-packages/oct2py/ipython/octavemagic.pyc in octave(self, line, cell, local_ns)
#
# /usr/local/lib/python2.7/dist-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/oct2py/ipython/octavemagic.pyc in octave(self, line, cell, local_ns)
#     312             msg = re.sub('"""\s+', '"""\n', msg)
#     313             msg = re.sub('\s+"""', '\n"""', msg)
# --> 314             raise OctaveMagicError(msg)
#     315
#     316         key = 'OctaveMagic.Octave'
#
# OctaveMagicError: Oct2Py tried to run:
# """
# M = [1/3,1/4,1/5; 1/4,1/5,1/6; 1/5,1/6,1/7]
#
# #transpose = transpose(M)
#
# inverse=inv(M)
#
# determinant=det(M)
#
# #rank=rank(M)
#
# #trace=trace(M)
#
# numeric(svd (M))
# """
# Octave returned:
# M =
#
#   0.33333  0.25000  0.20000
#   0.25000  0.20000  0.16667
#   0.20000  0.16667  0.14286
#
# inverse =
#
#   1.0e+03  *
#
#   0.30000  -0.90000  0.63000
#   -0.90000  2.88000  -2.10000
#   0.63000  -2.10000  1.57500
#
# determinant =    2.6455e-06
# 'numeric' undefined near line 16 column 1
