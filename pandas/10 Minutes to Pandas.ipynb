# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hr="--------------------------------------------------------------------------------------------------------------------------"
s=pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
dates=pd.date_range("20140101",periods=6)
print dates
df=pd.DataFrame(np.random.randn(6,4)
                ,index=dates
                ,columns=list("ABCD")
                )
df
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-01-01, ..., 2014-01-06]
# Length: 6, Freq: D, Timezone: None
#                    A         B         C         D
# 2014-01-01  0.246287  0.897897  0.787693 -1.393341
# 2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
# 2014-01-03  1.702639 -0.272205  0.016183  0.060847
# 2014-01-04  0.573254 -1.768530  0.090060  1.265139
# 2014-01-05  1.159015  1.289275 -0.106302  0.944684
# 2014-01-06  0.975977  0.137149 -0.592113  0.729510

# %%
df2=pd.DataFrame({"A":1.,
                  "B":pd.Timestamp("20130102"),
                  "C":pd.Series(1,index=list(range(5)),dtype="float32"),
                  "D":np.array([3]*5,dtype="int32"),
                  "E":"foo"
                  })
df2
# Out:
#    A          B  C  D    E
# 0  1 2013-01-02  1  3  foo
# 1  1 2013-01-02  1  3  foo
# 2  1 2013-01-02  1  3  foo
# 3  1 2013-01-02  1  3  foo
# 4  1 2013-01-02  1  3  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2014-01-01  0.246287  0.897897  0.787693 -1.393341
# 2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
# 2014-01-03  1.702639 -0.272205  0.016183  0.060847
# 2014-01-04  0.573254 -1.768530  0.090060  1.265139
# 2014-01-05  1.159015  1.289275 -0.106302  0.944684

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2014-01-04  0.573254 -1.768530  0.090060  1.265139
# 2014-01-05  1.159015  1.289275 -0.106302  0.944684
# 2014-01-06  0.975977  0.137149 -0.592113  0.729510

# %%
df.index,hr,df.columns,hr,df.values,hr,df.describe()
# Out:
# (<class 'pandas.tseries.index.DatetimeIndex'>
#  [2014-01-01, ..., 2014-01-06]
#  Length: 6, Freq: D, Timezone: None,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  Index([u'A', u'B', u'C', u'D'], dtype='object'),
#  '--------------------------------------------------------------------------------------------------------------------------',
#  array([[ 0.24628748,  0.8978971 ,  0.78769332, -1.39334127],
#         [-0.59571042, -0.22220818, -1.25118581,  0.52113968],
#         [ 1.70263946, -0.2722046 ,  0.01618316,  0.06084664],
#         [ 0.57325403, -1.76852968,  0.09006038,  1.26513875],
#         [ 1.15901499,  1.28927498, -0.10630239,  0.94468353],
#         [ 0.97597712,  0.13714902, -0.59211333,  0.72950989]]),
#  '--------------------------------------------------------------------------------------------------------------------------',
#                A         B         C         D
# ...

# %%
df.T
# Out:
#    2014-01-01  2014-01-02  2014-01-03  2014-01-04  2014-01-05  2014-01-06
# A    0.246287   -0.595710    1.702639    0.573254    1.159015    0.975977
# B    0.897897   -0.222208   -0.272205   -1.768530    1.289275    0.137149
# C    0.787693   -1.251186    0.016183    0.090060   -0.106302   -0.592113
# D   -1.393341    0.521140    0.060847    1.265139    0.944684    0.729510

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2014-01-01 -1.393341  0.787693  0.897897  0.246287
# 2014-01-02  0.521140 -1.251186 -0.222208 -0.595710
# 2014-01-03  0.060847  0.016183 -0.272205  1.702639
# 2014-01-04  1.265139  0.090060 -1.768530  0.573254
# 2014-01-05  0.944684 -0.106302  1.289275  1.159015
# 2014-01-06  0.729510 -0.592113  0.137149  0.975977

# %%
df.sort(columns="B")
# Out:
#                    A         B         C         D
# 2014-01-04  0.573254 -1.768530  0.090060  1.265139
# 2014-01-03  1.702639 -0.272205  0.016183  0.060847
# 2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
# 2014-01-06  0.975977  0.137149 -0.592113  0.729510
# 2014-01-01  0.246287  0.897897  0.787693 -1.393341
# 2014-01-05  1.159015  1.289275 -0.106302  0.944684

# %%
df['A'],hr,df[0:3],hr,df["20140102":"20140104"]
# Out:
# (2014-01-01    0.246287
#  2014-01-02   -0.595710
#  2014-01-03    1.702639
#  2014-01-04    0.573254
#  2014-01-05    1.159015
#  2014-01-06    0.975977
#  Freq: D, Name: A, dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2014-01-01  0.246287  0.897897  0.787693 -1.393341
#  2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847
#  2014-01-04  0.573254 -1.768530  0.090060  1.265139)

# %%
df.loc[dates[0]],hr,df.loc[:,['A','B']],hr,df.loc['20140102':'20140104',['A','B']],hr,df.loc['20140102',['A','B']],hr
# Out:
# (A    0.246287
#  B    0.897897
#  C    0.787693
#  D   -1.393341
#  Name: 2014-01-01 00:00:00, dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B
#  2014-01-01  0.246287  0.897897
#  2014-01-02 -0.595710 -0.222208
#  2014-01-03  1.702639 -0.272205
#  2014-01-04  0.573254 -1.768530
#  2014-01-05  1.159015  1.289275
#  2014-01-06  0.975977  0.137149,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B
#  2014-01-02 -0.595710 -0.222208
#  2014-01-03  1.702639 -0.272205
#  2014-01-04  0.573254 -1.768530,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  A   -0.595710
#  B   -0.222208
#  Name: 2014-01-02 00:00:00, dtype: float64,
# ...

# %%
df.loc[dates[0],"A"],hr,df.at[dates[0],"A"]
# Out:
# (0.24628748380835958,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  0.24628748380835958)

# %%
df.iloc[3],hr,df.iloc[3:5,0:2],hr,df.iloc[[1,2,4],[0,2]],hr,df.iloc[1:3,:],hr,df.iloc[:,1:3],hr,df.iloc[1,1],hr,df.iat[1,1]
# Out:
# (A    0.573254
#  B   -1.768530
#  C    0.090060
#  D    1.265139
#  Name: 2014-01-04 00:00:00, dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B
#  2014-01-04  0.573254 -1.768530
#  2014-01-05  1.159015  1.289275,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         C
#  2014-01-02 -0.595710 -1.251186
#  2014-01-03  1.702639  0.016183
#  2014-01-05  1.159015 -0.106302,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2014-01-02 -0.595710 -0.222208 -1.251186  0.521140
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847,
# ...

# %%
df[df.A > 0],hr,df[df > 0]
# Out:
# (                   A         B         C         D
#  2014-01-01  0.246287  0.897897  0.787693 -1.393341
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847
#  2014-01-04  0.573254 -1.768530  0.090060  1.265139
#  2014-01-05  1.159015  1.289275 -0.106302  0.944684
#  2014-01-06  0.975977  0.137149 -0.592113  0.729510,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2014-01-01  0.246287  0.897897  0.787693       NaN
#  2014-01-02       NaN       NaN       NaN  0.521140
#  2014-01-03  1.702639       NaN  0.016183  0.060847
#  2014-01-04  0.573254       NaN  0.090060  1.265139
#  2014-01-05  1.159015  1.289275       NaN  0.944684
#  2014-01-06  0.975977  0.137149       NaN  0.729510)

# %%
df2 = df.copy()
df2["E"]=["one","one","two","three","four","three"]
df2,hr,df2[df2["E"].isin(["two","four"])]
# Out:
# (                   A         B         C         D      E
#  2014-01-01  0.246287  0.897897  0.787693 -1.393341    one
#  2014-01-02 -0.595710 -0.222208 -1.251186  0.521140    one
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847    two
#  2014-01-04  0.573254 -1.768530  0.090060  1.265139  three
#  2014-01-05  1.159015  1.289275 -0.106302  0.944684   four
#  2014-01-06  0.975977  0.137149 -0.592113  0.729510  three,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D     E
#  2014-01-03  1.702639 -0.272205  0.016183  0.060847   two
#  2014-01-05  1.159015  1.289275 -0.106302  0.944684  four)

# %%
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range("20140102",periods=6))
s1
# Out:
# 2014-01-02    1
# 2014-01-03    2
# 2014-01-04    3
# 2014-01-05    4
# 2014-01-06    5
# 2014-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1
df.at[dates[0],"A"] = 0
df.iat[0,1] = 0
df.loc[:,"D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C  D   F
# 2014-01-01  0.000000  0.000000  0.787693  5 NaN
# 2014-01-02 -0.595710 -0.222208 -1.251186  5   1
# 2014-01-03  1.702639 -0.272205  0.016183  5   2
# 2014-01-04  0.573254 -1.768530  0.090060  5   3
# 2014-01-05  1.159015  1.289275 -0.106302  5   4
# 2014-01-06  0.975977  0.137149 -0.592113  5   5

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D   F
# 2014-01-01  0.000000  0.000000 -0.787693 -5 NaN
# 2014-01-02 -0.595710 -0.222208 -1.251186 -5  -1
# 2014-01-03 -1.702639 -0.272205 -0.016183 -5  -2
# 2014-01-04 -0.573254 -1.768530 -0.090060 -5  -3
# 2014-01-05 -1.159015 -1.289275 -0.106302 -5  -4
# 2014-01-06 -0.975977 -0.137149 -0.592113 -5  -5

# %% [markdown]
# #Missing Data

# %%
df1 = df.reindex(index=dates[0:4],columns=list(df.columns) + ["E"])
df1.loc[dates[0]:dates[1],"E"] = 1

df1,hr,df1.dropna(how="any"),hr,df1.fillna(value=5),hr,pd.isnull(df1)
# Out:
# (                   A         B         C  D   F   E
#  2014-01-01  0.000000  0.000000  0.787693  5 NaN   1
#  2014-01-02 -0.595710 -0.222208 -1.251186  5   1   1
#  2014-01-03  1.702639 -0.272205  0.016183  5   2 NaN
#  2014-01-04  0.573254 -1.768530  0.090060  5   3 NaN,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                    A         B         C  D  F  E
#  2014-01-02 -0.59571 -0.222208 -1.251186  5  1  1,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C  D  F  E
#  2014-01-01  0.000000  0.000000  0.787693  5  5  1
#  2014-01-02 -0.595710 -0.222208 -1.251186  5  1  1
#  2014-01-03  1.702639 -0.272205  0.016183  5  2  5
#  2014-01-04  0.573254 -1.768530  0.090060  5  3  5,
# ...

# %%
df.mean(),hr,df.mean(1)
# Out:
# (A    0.635863
#  B   -0.139420
#  C   -0.175944
#  D    5.000000
#  F    3.000000
#  dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2014-01-01    1.446923
#  2014-01-02    0.786179
#  2014-01-03    1.689324
#  2014-01-04    1.378957
#  2014-01-05    2.268398
#  2014-01-06    2.104203
#  Freq: D, dtype: float64)

# %%
s = pd.Series([1,3,5,np.nan,6,8],index=dates).shift(2)

s,df.sub(s,axis="index")
# Out:
# (2014-01-01   NaN
#  2014-01-02   NaN
#  2014-01-03     1
#  2014-01-04     3
#  2014-01-05     5
#  2014-01-06   NaN
#  Freq: D, dtype: float64,                    A         B         C   D   F
#  2014-01-01       NaN       NaN       NaN NaN NaN
#  2014-01-02       NaN       NaN       NaN NaN NaN
#  2014-01-03  0.702639 -1.272205 -0.983817   4   1
#  2014-01-04 -2.426746 -4.768530 -2.909940   2   0
#  2014-01-05 -3.840985 -3.710725 -5.106302   0  -1
#  2014-01-06       NaN       NaN       NaN NaN NaN)

# %%
df.apply(np.cumsum)

df
# Out:
#                    A         B         C  D   F
# 2014-01-01  0.000000  0.000000  0.787693  5 NaN
# 2014-01-02 -0.595710 -0.222208 -1.251186  5   1
# 2014-01-03  1.702639 -0.272205  0.016183  5   2
# 2014-01-04  0.573254 -1.768530  0.090060  5   3
# 2014-01-05  1.159015  1.289275 -0.106302  5   4
# 2014-01-06  0.975977  0.137149 -0.592113  5   5

# %%
df.apply(lambda x: x.max() - x.min())
df
# Out:
#                    A         B         C  D   F
# 2014-01-01  0.000000  0.000000  0.787693  5 NaN
# 2014-01-02 -0.595710 -0.222208 -1.251186  5   1
# 2014-01-03  1.702639 -0.272205  0.016183  5   2
# 2014-01-04  0.573254 -1.768530  0.090060  5   3
# 2014-01-05  1.159015  1.289275 -0.106302  5   4
# 2014-01-06  0.975977  0.137149 -0.592113  5   5

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s,hr,s.value_counts()
# Out:
# (0    6
#  1    1
#  2    2
#  3    2
#  4    4
#  5    5
#  6    1
#  7    4
#  8    3
#  9    5
#  dtype: int64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  5    2
#  4    2
#  2    2
#  1    2
#  6    1
#  3    1
#  dtype: int64)

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.326061  1.127472  1.271023 -0.411906
# 1 -0.732044  0.721868  1.016891 -0.081566
# 2 -0.690387  0.557688  0.920417 -0.322620
# 3  0.613019 -0.920898 -0.448431  0.300365
# 4  1.424339 -0.455250  1.080609 -0.632933
# 5 -1.096359 -0.780491 -0.784335  0.139726
# 6 -1.851112 -0.691156 -1.933433  0.206999
# 7  0.771610  0.543926  1.057766  0.229576
# 8 -1.245688 -0.051832  0.403440 -1.411731
# 9  0.733821 -0.896713  1.360297  0.354132

# %%
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.326061  1.127472  1.271023 -0.411906
# 1 -0.732044  0.721868  1.016891 -0.081566
# 2 -0.690387  0.557688  0.920417 -0.322620
# 3  0.613019 -0.920898 -0.448431  0.300365
# 4  1.424339 -0.455250  1.080609 -0.632933
# 5 -1.096359 -0.780491 -0.784335  0.139726
# 6 -1.851112 -0.691156 -1.933433  0.206999
# 7  0.771610  0.543926  1.057766  0.229576
# 8 -1.245688 -0.051832  0.403440 -1.411731
# 9  0.733821 -0.896713  1.360297  0.354132

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left,hr,right,hr,pd.merge(left, right, on="key")
# Out:
# (   key  lval
#  0  foo     1
#  1  foo     2,
#  '--------------------------------------------------------------------------------------------------------------------------',
#     key  rval
#  0  foo     4
#  1  foo     5,
#  '--------------------------------------------------------------------------------------------------------------------------',
#     key  lval  rval
#  0  foo     1     4
#  1  foo     1     5
#  2  foo     2     4
#  3  foo     2     5)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=["A","B","C","D"])
df
# Out:
#           A         B         C         D
# 0  1.849194 -0.983574  0.235510  1.477733
# 1 -0.518336 -0.390811  1.991549  0.191168
# 2  1.513923  0.367734 -0.360259 -0.523870
# 3  1.332450 -0.033816 -0.130809  3.093912
# 4  1.081113 -0.563505  0.660042  1.438966
# 5 -0.361122 -1.673986  0.736729  0.247576
# 6  0.277851  1.640044 -1.830194  0.769536
# 7 -2.503221  0.147759  0.079579 -0.251879

# %%
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0  1.849194 -0.983574  0.235510  1.477733
# 1 -0.518336 -0.390811  1.991549  0.191168
# 2  1.513923  0.367734 -0.360259 -0.523870
# 3  1.332450 -0.033816 -0.130809  3.093912
# 4  1.081113 -0.563505  0.660042  1.438966
# 5 -0.361122 -1.673986  0.736729  0.247576
# 6  0.277851  1.640044 -1.830194  0.769536
# 7 -2.503221  0.147759  0.079579 -0.251879
# 8  1.332450 -0.033816 -0.130809  3.093912

# %%
df = pd.DataFrame({"A": ["foo", "bar", "foo", "bar",
"foo", "bar", "foo", "foo"],
"B" : ["one", "one", "two", "three",
"two", "two", "one", "three"],
"C" : np.random.randn(8),
"D" : np.random.randn(8)})

df
# Out:
#      A      B         C         D
# 0  foo    one -1.330418  2.036064
# 1  bar    one  0.242523 -1.840300
# 2  foo    two -2.577839  0.477567
# 3  bar  three  0.357226  0.712558
# 4  foo    two -1.165997  1.698715
# 5  bar    two -1.237299  1.290288
# 6  foo    one -0.734883  0.260194
# 7  foo  three  1.304656  0.333815

# %%
df.groupby("A").sum(),hr,df.groupby(["A","B"]).sum()
# Out:
# (           C         D
#  A
#  bar -0.63755  0.162545
#  foo -4.50448  4.806356,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                    C         D
#  A   B
#  bar one    0.242523 -1.840300
#      three  0.357226  0.712558
#      two   -1.237299  1.290288
#  foo one   -2.065301  2.296258
#      three  1.304656  0.333815
#      two   -3.743835  2.176282)

# %%
tuples = list(zip(*[["bar", "bar", "baz", "baz",
"foo", "foo", "qux", "qux"],
["one", "two", "one", "two",
"one", "two", "one", "two"]]))

tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df
# Out:
#                      A         B
# first second
# bar   one     0.881532  1.464216
#       two    -1.655268  0.572460
# baz   one     0.553702  0.850847
#       two     1.827795 -0.157912
# foo   one    -0.758402  0.643313
#       two     0.190989  1.204579
# qux   one     0.532524  0.368326
#       two    -1.148403 -0.288623

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.881532  1.464216
#       two    -1.655268  0.572460
# baz   one     0.553702  0.850847
#       two     1.827795 -0.157912

# %%
stacked = df2.stack()
stacked,hr,stacked.unstack(),hr,stacked.unstack(0),hr,stacked.unstack(1)
# Out:
# (first  second
#  bar    one     A    0.881532
#                 B    1.464216
#         two     A   -1.655268
#                 B    0.572460
#  baz    one     A    0.553702
#                 B    0.850847
#         two     A    1.827795
#                 B   -0.157912
#  dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#                       A         B
#  first second
#  bar   one     0.881532  1.464216
#        two    -1.655268  0.572460
#  baz   one     0.553702  0.850847
#        two     1.827795 -0.157912,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  first          bar       baz
#  second
#  one    A  0.881532  0.553702
#         B  1.464216  0.850847
#  two    A -1.655268  1.827795
#         B  0.572460 -0.157912,
# ...

# %%
df = pd.DataFrame({"A" : ["one", "one", "two", "three"] * 3,
"B" : ["A", "B", "C"] * 4,
"C" : ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
"D" : np.random.randn(12),
"E" : np.random.randn(12)})

df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.742681  0.153297
# 1     one  B  foo  1.638777  0.548399
# 2     two  C  foo  0.445763  0.116082
# 3   three  A  bar -1.882380  0.564581
# 4     one  B  bar  0.354287 -1.743128
# 5     one  C  bar  0.918260 -0.650849
# 6     two  A  foo  0.804438  0.474696
# 7   three  B  foo -0.293370 -1.894464
# 8     one  C  foo -0.044612  0.507797
# 9     one  A  bar  1.376998  1.611919
# 10    two  B  bar  1.436030  1.287705
# 11  three  C  bar -0.984252 -0.758489

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  1.376998 -0.742681
#       B  0.354287  1.638777
#       C  0.918260 -0.044612
# three A -1.882380       NaN
#       B       NaN -0.293370
#       C -0.984252       NaN
# two   A       NaN  0.804438
#       B  1.436030       NaN
#       C       NaN  0.445763

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
rng,hr,ts,hr,ts.resample("5Min", how="sum")
# Out:
# (<class 'pandas.tseries.index.DatetimeIndex'>
#  [2012-01-01 00:00:00, ..., 2012-01-01 00:01:39]
#  Length: 100, Freq: S, Timezone: None,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2012-01-01 00:00:00    477
#  2012-01-01 00:00:01    345
#  2012-01-01 00:00:02    199
#  2012-01-01 00:00:03    252
#  2012-01-01 00:00:04    460
#  2012-01-01 00:00:05    399
#  2012-01-01 00:00:06     14
#  2012-01-01 00:00:07     39
#  2012-01-01 00:00:08    180
#  2012-01-01 00:00:09    200
#  2012-01-01 00:00:10     77
#  2012-01-01 00:00:11    120
#  2012-01-01 00:00:12    443
#  2012-01-01 00:00:13    424
#  2012-01-01 00:00:14    278
#  ...
#  2012-01-01 00:01:25    122
#  2012-01-01 00:01:26    274
#  2012-01-01 00:01:27    388
#  2012-01-01 00:01:28    471
#  2012-01-01 00:01:29    413
#  2012-01-01 00:01:30    280
#  2012-01-01 00:01:31    200
#  2012-01-01 00:01:32    496
#  2012-01-01 00:01:33    235
# ...

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
rng,hr,ts
# Out:
# (<class 'pandas.tseries.index.DatetimeIndex'>
#  [2012-03-06, ..., 2012-03-10]
#  Length: 5, Freq: D, Timezone: None,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2012-03-06    1.388277
#  2012-03-07    0.447990
#  2012-03-08   -0.088181
#  2012-03-09    0.390864
#  2012-03-10   -0.691946
#  Freq: D, dtype: float64)

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc,hr,ts_utc.tz_convert("US/Eastern")
# Out:
# (2012-03-06 00:00:00+00:00    1.388277
#  2012-03-07 00:00:00+00:00    0.447990
#  2012-03-08 00:00:00+00:00   -0.088181
#  2012-03-09 00:00:00+00:00    0.390864
#  2012-03-10 00:00:00+00:00   -0.691946
#  Freq: D, dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2012-03-05 19:00:00-05:00    1.388277
#  2012-03-06 19:00:00-05:00    0.447990
#  2012-03-07 19:00:00-05:00   -0.088181
#  2012-03-08 19:00:00-05:00    0.390864
#  2012-03-09 19:00:00-05:00   -0.691946
#  Freq: D, dtype: float64)

# %%
rng = pd.date_range("1/1/2012", periods=5, freq="M")
ts = pd.Series(np.random.randn(len(rng)), index=rng)
rng,hr,ts
# Out:
# (<class 'pandas.tseries.index.DatetimeIndex'>
#  [2012-01-31, ..., 2012-05-31]
#  Length: 5, Freq: M, Timezone: None,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2012-01-31   -0.367903
#  2012-02-29    1.461474
#  2012-03-31    0.653498
#  2012-04-30   -0.299472
#  2012-05-31    0.665088
#  Freq: M, dtype: float64)

# %%
ps = ts.to_period()
ps,hr,ps.to_timestamp()
# Out:
# (2012-01   -0.367903
#  2012-02    1.461474
#  2012-03    0.653498
#  2012-04   -0.299472
#  2012-05    0.665088
#  Freq: M, dtype: float64,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  2012-01-01   -0.367903
#  2012-02-01    1.461474
#  2012-03-01    0.653498
#  2012-04-01   -0.299472
#  2012-05-01    0.665088
#  Freq: MS, dtype: float64)

# %%
prng = pd.period_range("1990Q1", "2000Q4", freq="Q-NOV")
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
prng,hr,ts,hr,ts.head()
# Out:
# (<class 'pandas.tseries.period.PeriodIndex'>
#  [1990Q1, ..., 2000Q4]
#  Length: 44, Freq: Q-NOV,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  1990-03-01 09:00    0.464372
#  1990-06-01 09:00    0.365197
#  1990-09-01 09:00   -1.686979
#  1990-12-01 09:00   -1.321043
#  1991-03-01 09:00   -0.601638
#  1991-06-01 09:00    1.492878
#  1991-09-01 09:00   -0.453663
#  1991-12-01 09:00    1.208550
#  1992-03-01 09:00    0.803867
#  1992-06-01 09:00   -0.370373
#  1992-09-01 09:00    1.368745
#  1992-12-01 09:00    0.910476
#  1993-03-01 09:00    0.169206
#  1993-06-01 09:00    0.946698
#  1993-09-01 09:00   -0.545363
#  1993-12-01 09:00    2.907080
#  1994-03-01 09:00    0.146136
#  1994-06-01 09:00    0.643628
#  1994-09-01 09:00    0.848356
#  1994-12-01 09:00    1.155452
#  1995-03-01 09:00   -1.564960
#  1995-06-01 09:00   -1.618067
#  1995-09-01 09:00   -0.362264
#  1995-12-01 09:00   -0.238081
# ...

# %% [markdown]
# #Categoricals

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":["a", "b", "b", "a", "a", "e"]})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a < b < e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df.groupby("grade"),hr,df.groupby("grade").size()
# Out:
# (<pandas.core.groupby.DataFrameGroupBy object at 0x34186d0>,
#  '--------------------------------------------------------------------------------------------------------------------------',
#  grade
#  very bad      1
#  bad         NaN
#  medium      NaN
#  good          2
#  very good     3
#  dtype: float64)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
columns=["A", "B", "C", "D"])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc="best")
