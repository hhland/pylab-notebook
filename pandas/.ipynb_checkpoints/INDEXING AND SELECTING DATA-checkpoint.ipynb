# %%
# %pylab inline
from pandas import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hr="---------------------------------------------------------------------------------------------------------------------------"
dates = date_range("1/1/2000", periods=8)

df = DataFrame(randn(8, 4), index=dates, columns=[ "A" , "B", "C" , "D" ])

panel = Panel({ "one" : df, "two" : df - df.mean()})


dates,hr,df,hr,panel
# Out:
# (<class 'pandas.tseries.index.DatetimeIndex'>
#  [2000-01-01, ..., 2000-01-08]
#  Length: 8, Freq: D, Timezone: None,
#  '---------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2000-01-01 -0.513979 -0.365873 -1.463646  1.931791
#  2000-01-02 -1.344708  0.883623  2.230523 -0.614295
#  2000-01-03  0.552883 -0.344214 -1.727221  0.775061
#  2000-01-04 -1.279137  0.241208 -1.049284  0.592943
#  2000-01-05  0.055233  0.683557 -0.685254  0.247895
#  2000-01-06 -0.037972  0.276197  0.216231 -2.056485
#  2000-01-07 -0.352958  0.200933 -0.016479  1.295617
#  2000-01-08 -0.441700 -0.241551 -0.253033  0.854333,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  <class 'pandas.core.panel.Panel'>
#  Dimensions: 2 (items) x 8 (major_axis) x 4 (minor_axis)
#  Items axis: one to two
#  Major_axis axis: 2000-01-01 00:00:00 to 2000-01-08 00:00:00
#  Minor_axis axis: A to D)

# %%
s = df[ "A" ]

s,hr,s[dates[5]],hr,panel['two']
# Out:
# (2000-01-01   -0.513979
#  2000-01-02   -1.344708
#  2000-01-03    0.552883
#  2000-01-04   -1.279137
#  2000-01-05    0.055233
#  2000-01-06   -0.037972
#  2000-01-07   -0.352958
#  2000-01-08   -0.441700
#  Freq: D, Name: A, dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  -0.037971543586610694,
#  '---------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2000-01-01 -0.093687 -0.532608 -1.120126  1.553433
#  2000-01-02 -0.924415  0.716888  2.574043 -0.992653
#  2000-01-03  0.973175 -0.510949 -1.383701  0.396704
#  2000-01-04 -0.858845  0.074473 -0.705764  0.214585
#  2000-01-05  0.475525  0.516822 -0.341733 -0.130462
#  2000-01-06  0.382321  0.109462  0.559751 -2.434843
#  2000-01-07  0.067334  0.034198  0.327041  0.917260
#  2000-01-08 -0.021408 -0.408286  0.090487  0.475975)

# %%
df[[ "B" , "A" ]] = df[[ "A" , "B" ]]
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.365873 -0.513979 -1.463646  1.931791
# 2000-01-02  0.883623 -1.344708  2.230523 -0.614295
# 2000-01-03 -0.344214  0.552883 -1.727221  0.775061
# 2000-01-04  0.241208 -1.279137 -1.049284  0.592943
# 2000-01-05  0.683557  0.055233 -0.685254  0.247895
# 2000-01-06  0.276197 -0.037972  0.216231 -2.056485
# 2000-01-07  0.200933 -0.352958 -0.016479  1.295617
# 2000-01-08 -0.241551 -0.441700 -0.253033  0.854333

# %%
sa = Series([ 1, 2, 3],index=list("abc"))

dfa=df.copy()

sa,hr,sa.b,hr,dfa,hr,dfa.A
# Out:
# (a    1
#  b    2
#  c    3
#  dtype: int64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  2,
#  '---------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2000-01-01 -0.365873 -0.513979 -1.463646  1.931791
#  2000-01-02  0.883623 -1.344708  2.230523 -0.614295
#  2000-01-03 -0.344214  0.552883 -1.727221  0.775061
#  2000-01-04  0.241208 -1.279137 -1.049284  0.592943
#  2000-01-05  0.683557  0.055233 -0.685254  0.247895
#  2000-01-06  0.276197 -0.037972  0.216231 -2.056485
#  2000-01-07  0.200933 -0.352958 -0.016479  1.295617
#  2000-01-08 -0.241551 -0.441700 -0.253033  0.854333,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  2000-01-01   -0.365873
#  2000-01-02    0.883623
#  2000-01-03   -0.344214
#  2000-01-04    0.241208
#  2000-01-05    0.683557
#  2000-01-06    0.276197
#  2000-01-07    0.200933
#  2000-01-08   -0.241551
#  Freq: D, Name: A, dtype: float64)

# %%
panel.one
# Out:
#                    A         B         C         D
# 2000-01-01 -0.513979 -0.365873 -1.463646  1.931791
# 2000-01-02 -1.344708  0.883623  2.230523 -0.614295
# 2000-01-03  0.552883 -0.344214 -1.727221  0.775061
# 2000-01-04 -1.279137  0.241208 -1.049284  0.592943
# 2000-01-05  0.055233  0.683557 -0.685254  0.247895
# 2000-01-06 -0.037972  0.276197  0.216231 -2.056485
# 2000-01-07 -0.352958  0.200933 -0.016479  1.295617
# 2000-01-08 -0.441700 -0.241551 -0.253033  0.854333

# %%
sa.a=5

dfa[ "A" ] = list(range(len(dfa.index)))

sa,hr,dfa
# Out:
# (a    5
#  b    2
#  c    3
#  dtype: int64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#              A         B         C         D
#  2000-01-01  0 -0.513979 -1.463646  1.931791
#  2000-01-02  1 -1.344708  2.230523 -0.614295
#  2000-01-03  2  0.552883 -1.727221  0.775061
#  2000-01-04  3 -1.279137 -1.049284  0.592943
#  2000-01-05  4  0.055233 -0.685254  0.247895
#  2000-01-06  5 -0.037972  0.216231 -2.056485
#  2000-01-07  6 -0.352958 -0.016479  1.295617
#  2000-01-08  7 -0.441700 -0.253033  0.854333)

# %%
s[:5],hr,s[::2],hr,s[::-1]
# Out:
# (2000-01-01   -0.365873
#  2000-01-02    0.883623
#  2000-01-03   -0.344214
#  2000-01-04    0.241208
#  2000-01-05    0.683557
#  Freq: D, Name: A, dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  2000-01-01   -0.365873
#  2000-01-03   -0.344214
#  2000-01-05    0.683557
#  2000-01-07    0.200933
#  Freq: 2D, Name: A, dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  2000-01-08   -0.241551
#  2000-01-07    0.200933
#  2000-01-06    0.276197
#  2000-01-05    0.683557
#  2000-01-04    0.241208
#  2000-01-03   -0.344214
#  2000-01-02    0.883623
#  2000-01-01   -0.365873
#  Freq: -1D, Name: A, dtype: float64)

# %%
s2 = s.copy()
s2[: 5] = 0

s2,hr,df[:3],hr,df[::-1]
# Out:
# (2000-01-01    0.000000
#  2000-01-02    0.000000
#  2000-01-03    0.000000
#  2000-01-04    0.000000
#  2000-01-05    0.000000
#  2000-01-06    0.276197
#  2000-01-07    0.200933
#  2000-01-08   -0.241551
#  Freq: D, Name: A, dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2000-01-01 -0.365873 -0.513979 -1.463646  1.931791
#  2000-01-02  0.883623 -1.344708  2.230523 -0.614295
#  2000-01-03 -0.344214  0.552883 -1.727221  0.775061,
#  '---------------------------------------------------------------------------------------------------------------------------',
#                     A         B         C         D
#  2000-01-08 -0.241551 -0.441700 -0.253033  0.854333
#  2000-01-07  0.200933 -0.352958 -0.016479  1.295617
#  2000-01-06  0.276197 -0.037972  0.216231 -2.056485
#  2000-01-05  0.683557  0.055233 -0.685254  0.247895
#  2000-01-04  0.241208 -1.279137 -1.049284  0.592943
#  2000-01-03 -0.344214  0.552883 -1.727221  0.775061
#  2000-01-02  0.883623 -1.344708  2.230523 -0.614295
#  2000-01-01 -0.365873 -0.513979 -1.463646  1.931791)

# %%
s1 = Series(np.random.randn(6),index=list("abcdef"))

s1,hr,s1.loc["c":],hr,s1.loc["b"],hr
# Out:
# (a    0.953064
#  b   -0.558906
#  c    0.088349
#  d    0.467691
#  e   -0.195721
#  f    0.157565
#  dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  c    0.088349
#  d    0.467691
#  e   -0.195721
#  f    0.157565
#  dtype: float64,
#  '---------------------------------------------------------------------------------------------------------------------------',
#  -0.55890559827144948,
#  '---------------------------------------------------------------------------------------------------------------------------')

# %%
df1 = DataFrame(np.random.randn(6, 4),index=list("abcdef" ),columns=list("ABCD" ))

df1
# Out:
# array([[ 1.01903134,  0.59776107, -0.17310734, -0.31096229],
#        [-0.39178394, -0.80581692, -0.72168518, -1.21094621],
#        [ 0.87517734, -0.70765425, -0.30679973, -0.78906544],
#        [ 0.72357476,  1.9271129 , -2.12767077, -0.46166601],
#        [ 0.0431691 , -1.48195204, -0.31024818, -1.36582676],
#        [ 1.78187979,  0.64340801,  1.13489376, -0.76749979]])
