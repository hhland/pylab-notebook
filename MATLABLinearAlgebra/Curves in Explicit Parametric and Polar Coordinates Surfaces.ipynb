# %%
# %pylab inline
# %load_ext oct2py.ipython
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%octave
# x = [1 2 5 8 4 3 4 1 2 3 2];
# bar(x)

# %%
# %%octave
# x=-2.9:0.2:2.9
# bar(x,exp(-x.*x))
# Out:
# x =
#
#  Columns 1 through 8:
#
#   -2.90000  -2.70000  -2.50000  -2.30000  -2.10000  -1.90000  -1.70000  -1.50000
#
#  Columns 9 through 16:
#
#   -1.30000  -1.10000  -0.90000  -0.70000  -0.50000  -0.30000  -0.10000   0.10000
#
#  Columns 17 through 24:
#
#    0.30000   0.50000   0.70000   0.90000   1.10000   1.30000   1.50000   1.70000
#
#  Columns 25 through 30:
#
#    1.90000   2.10000   2.30000   2.50000   2.70000   2.90000

# %%
# %%octave
# A = [1 6 12 5 7; 3 2 6 5 3];
# bar (A, 'stacked')

# %%
# %octave bar (A, 'grouped')
# %octave barh(A,"grouped")

# %%
# %%octave
# barh(A,"grouped")

# %%
# %%octave
# Y=randn(50)
# Out:
# Y =
#
#  Columns 1 through 8:
#
#   1.07484  1.45462  -0.40008  -0.41380  -0.65605  0.50968  -0.16352  -0.95581
#   -1.65927  -0.13876  1.11947  2.11784  0.23210  0.22567  1.69898  1.32598
#   0.42140  -0.02697  0.36595  -0.39892  0.90344  0.45760  0.04218  0.57224
#   0.54552  -0.58610  -0.32874  -0.53543  -1.80426  0.85257  0.25281  0.15179
#   -0.51976  0.06975  -0.50218  -0.01823  0.01254  0.07419  -0.34658  0.17663
#   0.15950  -0.54165  -0.45273  -0.91345  -0.09050  0.83398  0.46382  0.54774
#   -0.40209  -0.39588  -0.74988  -0.74965  -0.81612  1.82126  0.33647  0.56427
#   -0.26202  -1.16933  2.14974  0.43820  -0.02447  0.27226  0.34356  0.24429
#   0.14413  -0.43269  0.10728  -2.03915  0.19187  -0.27550  -0.04572  0.79421
#   -0.11300  0.66727  0.14748  1.67508  -1.50035  0.89413  -0.94525  -1.19351
#   0.54218  1.31853  0.54235  -1.79732  -0.08860  -0.94671  0.34161  -0.50057
#   0.83431  -1.31601  0.58560  -0.24117  -0.47317  0.29203  -0.54241  -0.45562
# ...

# %%
# %octave hist(Y)
# %octave hist(Y,8)
