# %%
# %pylab inline
# %load_ext oct2py.ipython
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%octave
# x = 0:0.05:10;
# y = sin(x) .* exp(-0.4*x);
# plot(x,y)

# %%
# %octave ezplot('sin(x) * exp(-0.4*x)', [0,10])

# %%
# %octave fplot('sin(x) * exp(-0.4*x)', [0,10])

# %%
# %octave ezplot('x^2-y^4')

# %%
# %%octave
# t = 0:0.1:2*pi;
# x = 4 * cos(t) - cos(4*t);
# y = 4 * sin(t) - sin(4*t);
# plot(x,y)

# %%
# %octave ezplot('4*cos(t) - cos(4*t)', '4*sin(t) - sin(4*t)', [0, 2*pi])
