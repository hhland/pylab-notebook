# %%
# %pylab inline
# %reload_ext pig_magic
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
# .cm-s-ipython span.cm-variable-2{color:#05a}
# .cm-s-ipython span.cm-type{color:#804}
# </style>

# %%
# %%pig -x local
#
# REGISTER lib/piggybank.jar
# Out:
# 14/12/14 20:57:59 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 14/12/14 20:57:59 INFO pig.ExecTypeProvider: Picked LOCAL as the ExecType
# 2014-12-14 20:57:59,473 [main] INFO  org.apache.pig.Main - Apache Pig version 0.14.0 (r1640057) compiled Nov 16 2014, 18:02:05
# 2014-12-14 20:57:59,473 [main] INFO  org.apache.pig.Main - Logging error messages to: /d/git/mypylab/pig/pig_1418561879472.log
# 2014-12-14 20:57:59,532 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2014-12-14 20:57:59,990 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2014-12-14 20:58:00,139 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - fs.default.name is deprecated. Instead, use fs.defaultFS
# 2014-12-14 20:58:00,140 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# ...

# %%
# !mv tmp/piggybank.jar lib/
