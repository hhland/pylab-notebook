# %%
# !git add .
# !git commit -a -m "...."
# Out:
# [master 2e0ddf3] ....
#  302 files changed, 38553 insertions(+), 61 deletions(-)
#  create mode 100755 graphlab/.ipynb_checkpoints/SGraph-checkpoint.ipynb
#  create mode 100755 graphlab/.ipynb_checkpoints/Visualization-checkpoint.ipynb
#  create mode 100755 graphlab/.ipynb_checkpoints/follow_the_cryptocurrency-checkpoint.ipynb
#  create mode 100755 graphlab/.ipynb_checkpoints/hello world-checkpoint.ipynb
#  create mode 100755 graphlab/.ipynb_checkpoints/shell-checkpoint.ipynb
#  create mode 100755 graphlab/SGraph.ipynb
#  create mode 100755 graphlab/Visualization.ipynb
#  create mode 100755 graphlab/follow_the_cryptocurrency.ipynb
#  create mode 100755 graphlab/hello world.ipynb
#  create mode 100755 graphlab/james_bond/dir_archive.ini
#  create mode 100755 graphlab/james_bond/m_109cf92e.0000
#  create mode 100755 graphlab/james_bond/m_109cf92e.0001
#  create mode 100755 graphlab/james_bond/m_109cf92e.frame_idx
#  create mode 100755 graphlab/james_bond/m_109cf92e.sidx
# ...

# %%
# !git push
# Out:
# # On branch master
# # Your branch is ahead of 'origin/master' by 1 commit.
# #
# nothing to commit (working directory clean)

# %%
# Out:
# GIT-PUSH(1)                       Git Manual                       GIT-PUSH(1)
#
#
#
# E
#        git-push - Update remote refs along with associated objects
#
# S
# h [--all | --mirror | --tags] [-n | --dry-run] [--receive-pack=<git-receive-pack>]
#                   [--repo=<repository>] [-f | --force] [-v | --verbose] [-u | --set-upstream]
#                   [<repository> [<refspec>...]]
#
#
# N
#        Updates remote refs using local refs, while sending objects necessary
#        to complete the given refs.
#
#        You can make interesting things happen to a repository every time you
# -
# k(1).
#
# S
#        <repository>
#            The "remote" repository that is destination of a push operation.
#            This parameter can be either a URL (see the section GIT URLS below)
#            or the name of a remote (see the section REMOTES below).
#
#        <refspec>...
#            The format of a <refspec> parameter is an optional plus +, followed
# ...
