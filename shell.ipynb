# %%
# !git add .
# !git commit -a -m "...."
# Out:
# [master fd88150] ....
#  20 files changed, 4049 insertions(+), 9 deletions(-)
#  create mode 100644 sklearn/.ipynb_checkpoints/Comparison of LDA and PCA 2D projection of Iris dataset-checkpoint.ipynb
#  create mode 100755 sklearn/.ipynb_checkpoints/Concatenating multiple feature extraction methods-checkpoint.ipynb
#  create mode 100644 sklearn/.ipynb_checkpoints/Faces recognition example using eigenfaces and SVMs-checkpoint.ipynb
#  create mode 100755 sklearn/.ipynb_checkpoints/Generalized Linear Models-checkpoint.ipynb
#  create mode 100644 sklearn/.ipynb_checkpoints/Model selection with Probabilistic (PCA) and Factor Analysis (FA)-checkpoint.ipynb
#  create mode 100755 sklearn/.ipynb_checkpoints/Nearest Neighbors-checkpoint.ipynb
#  create mode 100755 sklearn/.ipynb_checkpoints/Recursive feature elimination-checkpoint.ipynb
#  create mode 100644 sklearn/Comparison of LDA and PCA 2D projection of Iris dataset.ipynb
# ...

# %%
# !git push
# Out:
# To https://github.com/hhland/mypylab.git
#    2e0ddf3..fd88150  master -> master

# %%
# Out:
# GIT-PUSH(1)                       Git Manual                       GIT-PUSH(1)
#
#
#
# E
#        git-push - Update remote refs along with associated objects
#
# S
# h [--all | --mirror | --tags] [-n | --dry-run] [--receive-pack=<git-receive-pack>]
#                   [--repo=<repository>] [-f | --force] [-v | --verbose] [-u | --set-upstream]
#                   [<repository> [<refspec>...]]
#
#
# N
#        Updates remote refs using local refs, while sending objects necessary
#        to complete the given refs.
#
#        You can make interesting things happen to a repository every time you
# -
# k(1).
#
# S
#        <repository>
#            The "remote" repository that is destination of a push operation.
#            This parameter can be either a URL (see the section GIT URLS below)
#            or the name of a remote (see the section REMOTES below).
#
#        <refspec>...
#            The format of a <refspec> parameter is an optional plus +, followed
# ...
