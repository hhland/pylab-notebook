# %%
!cat script/thinkbays.py | grep Suite
# Out:
# cat README-splunk.txt  script/thinkbays.py script/thinkbays.py | grep Suite
# cat: README-splunk.txt: No such file or directory
# class Suite(Pmf):
# def MakeSuiteFromList(t, name=''):
#         Suite object
#     return MakeSuiteFromDict(d)
# def MakeSuiteFromHist(hist, name=None):
#         Suite object
#     return MakeSuiteFromDict(d, name)
# def MakeSuiteFromDict(d, name=''):
#         Suite object
#     suite = Suite(name=name)
# def MakeSuiteFromCdf(cdf, name=None):
#     """Makes a normalized Suite from a Cdf object.
#         name: string name for the new Suite
#         Suite object
#     suite = Suite(name=name)
# class Suite(Pmf):
# def MakeSuiteFromList(t, name=''):
#         Suite object
#     return MakeSuiteFromDict(d)
# def MakeSuiteFromHist(hist, name=None):
#         Suite object
#     return MakeSuiteFromDict(d, name)
# def MakeSuiteFromDict(d, name=''):
#         Suite object
#     suite = Suite(name=name)
# def MakeSuiteFromCdf(cdf, name=None):
#     """Makes a normalized Suite from a Cdf object.
#         name: string name for the new Suite
#         Suite object
#     suite = Suite(name=name)

# %%
!cd script && wget https://raw.githubusercontent.com/AllenDowney/ThinkBayes/master/thinkplot.py
# Out:
# cd /d/www/ script && wget https://raw.githubusercontent.com/AllenDowney/ThinkBayes/master/thinkplot.py
# --2015-05-07 16:27:21--  https://raw.githubusercontent.com/AllenDowney/ThinkBayes/master/thinkplot.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.27.74.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.27.74.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12500 (12K) [text/plain]
# Saving to: `thinkplot.py'
#
# 100%[======================================>] 12,500      --.-K/s   in 0s
#
# 2015-05-07 16:27:22 (226 MB/s) - `thinkplot.py' saved [12500/12500]

# %%
!ls .
# Out:
# ls /d/download/ .
# .:
# avatar             github.js           linux-dash         rockmongo
# cacti-0.8.8c       gostop.swf          markdown-editor    shiny
# cdn                HexGL               MathMLEditor.swf   SQLyogTunnel.php
# Chess3D            hoorayos            Metro-UI           sugarcrm
# Defend-The-Den     html5-audio-editor  mykrkr_tp.swf      thinkplot.py
# devoops            HTML5-Minesweeper   Nemesis            three
# devoops2.zip       ICEcoder            phpHiveAdmin       vis
# docs               image               phpliteradmin.php  webian-shell
# elFinder           index.html          phpmyadmin         wwwhome.html
# essential-threejs  index.html.bak      phpmyadmin0        wx-lsf
# Flat-UI            index.php           py                 X2Engine
# fruit-ninja        KODExplorer         release
# gaga.html          korean.swf          results.png
#
# /d/download/:
# 4277_weboctave-0.1.0.zip
# activemq-cpp-library-3.8.3
# activemq-cpp-library-3.8.3-src.tar.gz
# ${activemq.data}
# apache-activemq-5.10.0
# apache-activemq-5.10.0-bin.tar.gz
# apache-cassandra-2.1.2-bin.tar.gz
# apache-continuum-1.4.2.war
# apache-hive-0.14.0-bin.tar.gz
# apache-hive-1.1.0-bin.tar.gz
# apache-lens-2.0.1-beta-incubating-bin.tar.gz
# apache-storm-0.9.3.tar.gz
# apache-tomcat-8.0.15.tar.gz
# auto-pairs-v1.3.2.tar.gz
# avro-1.7.7
# avro-1.7.7.tar.gz
# birt-charts.hpi
# build
# cacti-0.8.8c.tar.gz
# chukwa-incubating-src-0.5.0.tar.gz
# clojure-1.6.0.zip
# clojure-1.7.0-alpha4.zip
# cmake-3.0.1
# cmake-3.0.1.tar.gz
# ctags-5.8
# ctags-5.8.tar.gz
# dashboard-view.hpi
# data_browser_v1.1.15.jsp
# dejavu-master
# dejavu.zip
# designer.war
# drone-1.4.war
# dzzoffice1.1_SC_UTF8_Release20140701.zip
# gdal-1.11.1
# gdal-1.11.1.tar.gz
# GDD_0.1-13.1.tar.gz
# gen-py
# gerrit-2.9.4.war
# giraph-1.0.0.tar.gz
# go1.4.linux-amd64.tar.gz
# groovy-binary-2.3.7.zip
# hadoop-1.2.1.tar.gz
# hadoop-2.4.1-src.tar.gz
# hadoop-2.6.0.tar.gz
# hdf5-1.8.14
# hdf5-1.8.14.tar
# hive-0.12.0-bin.tar.gz
# hive-release-0.13.3-inm.tar.gz
# HoorayOS 2.0.0.zip
# hudson32
# hudson-3.2.1.war
# hydra-3.1.2
# hydra-3.1.2.tar.gz
# IScala-0.1
# IScala-0.1.tgz
# javabrowser
# javabrowser.zip
# javolution-5.4.3.1.jar
# jbpm-designer-2.4.0.Final-tomcat.war
# jdk-6u45-linux-x64.bin
# jdk-7u65-linux-x64.tar.gz
# jdk-8u20-linux-x64.tar.gz
# jenkins.war
# jna-native-support-plugin.hpi
# JPype-0.5.4.2
# JPype-0.5.4.2.zip
# jython-installer-2.7-b3.jar
# kafka_2.10-0.8.1.1.tgz
# kafka_2.11-0.8.2.1.tgz
# KeyBox-jetty
# keybox-jetty-v2.11_05.tar.gz
# lein
# lenskit-2.1.tar.gz
# LICENSE
# license.txt
# log
# lucid-1.0.1.tar.gz
# __MACOSX
# mahout-distribution-0.9.tar.gz
# mapreduce-v1.0.0.zip
# matechDES.dll
# matechJNI.jar
# memcached-session-manager-1.8.2.jar
# memcached-session-manager-tc7-1.8.2.jar
# mpich-3.1.2.tar.gz
# msm-flexjson-serializer-1.8.2.jar
# msm-javolution-serializer-1.8.2.jar
# msm-kryo-serializer-1.8.2.jar
# msm-xstream-serializer-1.8.2.jar
# neo4j-community-2.2.1-unix.tar.gz
# nerdtree
# nerdtree.zip
# newrelic
# newrelic-java-3.12.0.zip
# newrelic-php5-4.15.0.74-linux
# newrelic-php5-4.15.0.74-linux.tar.gz
# nginx-clojure-0.3.0
# nginx-clojure-0.3.0.tar.gz
# nifi-0.0.2-incubating-bin.tar.gz
# octave-3.8.1
# octave-3.8.1.tar.gz
# openmpi-1.8.1.tar.gz
# otp_src_17.3
# otp_src_17.3.tar.gz
# patsy-0.2.1
# patsy-0.2.1.tar.gz
# phpSQLiteAdmin-0.3a1.tar.gz
# pig-0.14.0.tar.gz
# pig_1418550680060.log
# pigtmp
# pigtutorial.tar.gz
# plyr_1.8.1.tar.gz
# postgresql-9.4.1
# postgresql-9.4.1.tar.gz
# protobuf-2.5.0
# protobuf-2.5.0.tar.gz
# pyactivemq-0.1.0
# pyactivemq-0.1.0.tar.gz
# pypy-2.5.1-linux64.tar.bz2
# qdPM_8.3.zip
# ranzhi.1.5.beta.zip
# README
# README.md
# readme.txt
# ReviewBoard-2.0.11.tar.gz
# rhdfs_1.0.8.tar.gz.1
# rockmongo-1.1.5.zip
# Rplots.pdf
# rstudio-server-0.98.978-amd64.deb
# sbt-0.13.5.tgz
# sharding-v1.0.0.zip
# shiny-server-1.1.0.10000-amd64.deb
# shogun-3.2.0
# shogun-3.2.0.tar.bz2
# spark-1.2.0-bin-hadoop2.4.tgz
# splunklight-6.2.2-255606-Linux-x86_64.tgz
# spymemcached-2.11.1.jar
# sqlite-jdbc-3.8.6.jar
# sqoop-1.4.4.bin__hadoop-1.0.0.tar.gz
# subversion.hpi
# SugarCE-6.5.16.zip
# Svdfeature-1.2.2.tar.gz
# systemjs-v1.0.0.zip
# taglist
# taglist_46
# taglist_46.zip
# tcpd-7.6-899.3.x86_64.rpm
# tez-0.4.1-incubating-src.tar.gz
# thrift-0.9.1.tar.gz
# TianjianERP.war
# tomcat-native-1.1.32-src
# tomcat-native-1.1.32-src.tar.gz
# vjde
# vjde.tgz
# webbuilder.zip
# WebShell-0.9.6
# WebShell-0.9.6.zip
# wget-log
# wget-log.1
# wide
# wide-1.1.0
# wide-1.1.0-linux-amd64.tar.gz
# zeromq-3.2.5
# zeromq-3.2.5.tar.gz
# zookeeper-3.4.6.tar.gz
