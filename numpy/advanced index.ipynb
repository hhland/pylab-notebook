# %%
# %pylab inline
import scipy.misc

# %%
lena=scipy.misc.lena()
xmax,ymax=lena.shape[0],lena.shape[1]

plt.subplot(221)
plt.imshow(lena)

# %%
lena_x=lena.copy()
yrange=range(ymax);
lena_x[range(xmax),yrange)]=0
lena_x[range(xmax),yrange[::-1]]=0
plt.subplot(222)
plt.imshow(lena_x)
# Out:
#   File "<ipython-input-15-04138994c8d9>", line 3
#     lena_x[range(xmax),yrange)]=0
#                              ^
# SyntaxError: invalid syntax
