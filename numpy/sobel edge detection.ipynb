# %%
# %pylab inline
import scipy
import scipy.ndimage as ndimage
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
lena=scipy.misc.lena()
plt.subplot(221)
plt.imshow(lena)
plt.title("original")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
lena_sobel_x=ndimage.sobel(lena,axis=0,mode="constant")
plt.subplot(222)
plt.imshow(lena_sobel_x)
plt.title("sobel x")
plt.axis("off")

lena_sobel_y=ndimage.sobel(lena,axis=1,mode="constant")
plt.subplot(223)
plt.imshow(lena_sobel_y)
plt.title("sobel y")
plt.axis("off")

lena_sobel=ndimage.sobel(lena)
plt.subplot(224)
plt.imshow(lena_sobel)
plt.title("sobel default")
plt.axis("off")
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
ndimage.sobel?
